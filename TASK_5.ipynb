# %% [markdown]
# <a href="https://colab.research.google.com/github/TECH-KAVIN/DATA-SCIENCE-PROJECT-/blob/main/TASK_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #DATA SCIENCE FOR BEGINNERS

# %%
from google. colab import drive
drive. mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np # linear algebra
import matplotlib.pyplot as plt
import seaborn as sns  # visualization tool
data=pd.read_csv("/content/Matic Historical Data.csv")
data
# Out:
#               Date  Price   Open   High    Low     Vol. Change %
# 0     May 06, 2023  0.987  0.998  1.004  0.986   58.61M   -1.01%
# 1     May 05, 2023  0.998  0.982  1.008  0.980   57.69M    1.52%
# 2     May 04, 2023  0.983  1.006  1.008  0.979   49.01M   -2.30%
# 3     May 03, 2023  1.006  0.977  1.017  0.964   89.57M    2.98%
# 4     May 02, 2023  0.977  0.959  0.980  0.953   54.11M    1.80%
# ...            ...    ...    ...    ...    ...      ...      ...
# 1405  Jul 01, 2019  0.022  0.022  0.023  0.020  974.46M    0.00%
# 1406  Jun 30, 2019  0.022  0.024  0.027  0.022    1.52B   -8.24%
# 1407  Jun 29, 2019  0.024  0.019  0.027  0.019    1.79B   25.71%
# 1408  Jun 28, 2019  0.019  0.019  0.021  0.019  929.60M    0.00%
# 1409  Jun 27, 2019  0.019  0.018  0.022  0.017    1.56B    8.10%
#
# [1410 rows x 7 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %%
data.head()
# Out:
#            Date  Price   Open   High    Low    Vol. Change %
# 0  May 06, 2023  0.987  0.998  1.004  0.986  58.61M   -1.01%
# 1  May 05, 2023  0.998  0.982  1.008  0.980  57.69M    1.52%
# 2  May 04, 2023  0.983  1.006  1.008  0.979  49.01M   -2.30%
# 3  May 03, 2023  1.006  0.977  1.017  0.964  89.57M    2.98%
# 4  May 02, 2023  0.977  0.959  0.980  0.953  54.11M    1.80%

# %%
data.tail()
# Out:
#               Date  Price   Open   High    Low     Vol. Change %
# 1405  Jul 01, 2019  0.022  0.022  0.023  0.020  974.46M    0.00%
# 1406  Jun 30, 2019  0.022  0.024  0.027  0.022    1.52B   -8.24%
# 1407  Jun 29, 2019  0.024  0.019  0.027  0.019    1.79B   25.71%
# 1408  Jun 28, 2019  0.019  0.019  0.021  0.019  929.60M    0.00%
# 1409  Jun 27, 2019  0.019  0.018  0.022  0.017    1.56B    8.10%

# %%
data.corr()
# Out:
# <ipython-input-14-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#           Price      Open      High       Low
# Price  1.000000  0.994558  0.997526  0.996609
# Open   0.994558  1.000000  0.996636  0.995802
# High   0.997526  0.996636  1.000000  0.993456
# Low    0.996609  0.995802  0.993456  1.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Price'].plot(kind='hist', bins=20, title='Price')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Open'].plot(kind='hist', bins=20, title='Open')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1410 entries, 0 to 1409
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1410 non-null   object
#  1   Price     1410 non-null   float64
#  2   Open      1410 non-null   float64
#  3   High      1410 non-null   float64
#  4   Low       1410 non-null   float64
#  5   Vol.      1410 non-null   object
#  6   Change %  1410 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 77.2+ KB

# %%
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()
# Out:
# <ipython-input-16-36a057762ca3>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)

# %%
data.columns
# Out:
# Index(['Date', 'Price', 'Open', 'High', 'Low', 'Vol.', 'Change %'], dtype='object')

# %%
# Scatter Plot
# x = High, y = Low
data.plot(kind='scatter', x='High', y='Low',alpha = 0.4,color = 'green')
plt.xlabel('High')              # label = name of label
plt.ylabel('Low')
plt.title('Points table')
# Out:
# Text(0.5, 1.0, 'Points table')

# %%
data.dropna
# Out:
# <bound method DataFrame.dropna of               Date  Price   Open   High    Low     Vol. Change %
# 0     May 06, 2023  0.987  0.998  1.004  0.986   58.61M   -1.01%
# 1     May 05, 2023  0.998  0.982  1.008  0.980   57.69M    1.52%
# 2     May 04, 2023  0.983  1.006  1.008  0.979   49.01M   -2.30%
# 3     May 03, 2023  1.006  0.977  1.017  0.964   89.57M    2.98%
# 4     May 02, 2023  0.977  0.959  0.980  0.953   54.11M    1.80%
# ...            ...    ...    ...    ...    ...      ...      ...
# 1405  Jul 01, 2019  0.022  0.022  0.023  0.020  974.46M    0.00%
# 1406  Jun 30, 2019  0.022  0.024  0.027  0.022    1.52B   -8.24%
# 1407  Jun 29, 2019  0.024  0.019  0.027  0.019    1.79B   25.71%
# 1408  Jun 28, 2019  0.019  0.019  0.021  0.019  929.60M    0.00%
# 1409  Jun 27, 2019  0.019  0.018  0.022  0.017    1.56B    8.10%
#
# [1410 rows x 7 columns]>

# %%
print(data.dtypes)
# Out:
# Date         object
# Price       float64
# Open        float64
# High        float64
# Low         float64
# Vol.         object
# Change %     object
# dtype: object

# %%
sns.histplot
# Out:
# <function seaborn.distributions.histplot(data=None, *, x=None, y=None, hue=None, weights=None, stat='count', bins='auto', binwidth=None, binrange=None, discrete=None, cumulative=False, common_bins=True, common_norm=True, multiple='layer', element='bars', fill=True, shrink=1, kde=False, kde_kws=None, line_kws=None, thresh=0, pthresh=None, pmax=None, cbar=False, cbar_ax=None, cbar_kws=None, palette=None, hue_order=None, hue_norm=None, color=None, log_scale=None, legend=True, ax=None, **kwargs)>
